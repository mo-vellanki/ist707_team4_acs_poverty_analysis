# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Dataset
# ### CSV file needs some trimming before using it here. Columns not used and empty columns are removed

# %%
data17 = pd.read_csv("../Data/2017/2017_trimmed.csv", header=[0,1])

# %%
#test

# %% [markdown]
# # Working dataset copy

# %%
df = data17.copy()

# %%
df.head()
# Out:
#   Name of Area Total Population                \
#       Geo_NAME    SE_A00001_001 SE_A00002_001
# 0  00601 ZCTA5            17599         17599
# 1  00602 ZCTA5            39209         39209
# 2  00603 ZCTA5            50135         50135
# 3  00606 ZCTA5             6304          6304
# 4  00610 ZCTA5            27590         27590
#
#   Population Density (Per Sq. Mile)   Area (Land)   Area Total:  \
#                       SE_A00002_002 SE_A00002_003 SE_A00003_001
# 0                          273.4985     64.347708      64.65632
# 1                         1280.7820     30.613331      32.33005
# 2                         1585.8370     31.614216      31.68504
# 3                          148.9987     42.309101      42.31392
# 4                          768.1858     35.915790      37.52661
#
#   Area Total: Area (Land) Area Total: Area (Water) Total Population:  \
#             SE_A00003_002            SE_A00003_003     SE_A02001_001
# ...

# %%
df.shape
# Out:
# (33120, 2178)

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# ## Extract zip codes

# %%
df.insert(0, 'zip_code', df[('Name of Area', 'Geo_NAME')].astype(str).str[:5])
df.drop('Name of Area', axis =1, inplace=True)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_97412\1942355198.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop('Name of Area', axis =1, inplace=True)

# %%
df.head()
# Out:
#   zip_code Total Population               Population Density (Per Sq. Mile)  \
#               SE_A00001_001 SE_A00002_001                     SE_A00002_002
# 0    00601            17599         17599                          273.4985
# 1    00602            39209         39209                         1280.7820
# 2    00603            50135         50135                         1585.8370
# 3    00606             6304          6304                          148.9987
# 4    00610            27590         27590                          768.1858
#
#     Area (Land)   Area Total: Area Total: Area (Land)  \
#   SE_A00002_003 SE_A00003_001           SE_A00003_002
# 0     64.347708      64.65632                64.34771
# 1     30.613331      32.33005                30.61333
# 2     31.614216      31.68504                31.61422
# 3     42.309101      42.31392                42.30910
# 4     35.915790      37.52661                35.91579
#
# ...

# %%
df.drop(df.columns[1], axis = 1, inplace=True)
df.head()
# Out:
#       zip_code Total Population                \
#                   SE_A00001_001 SE_A00002_001
# 0  00601 ZCTA5            17599         17599
# 1  00602 ZCTA5            39209         39209
# 2  00603 ZCTA5            50135         50135
# 3  00606 ZCTA5             6304          6304
# 4          NaN            27590         27590
#
#   Population Density (Per Sq. Mile)   Area (Land)   Area Total:  \
#                       SE_A00002_002 SE_A00002_003 SE_A00003_001
# 0                          273.4985     64.347708      64.65632
# 1                         1280.7820     30.613331      32.33005
# 2                         1585.8370     31.614216      31.68504
# 3                          148.9987     42.309101      42.31392
# 4                          768.1858     35.915790      37.52661
#
#   Area Total: Area (Land) Area Total: Area (Water) Total Population:  \
#             SE_A00003_002            SE_A00003_003     SE_A02001_001
# ...

# %% [markdown]
# ### Getting columns by searching for table names in second level of header

# %%
df.loc[:, df.columns.get_level_values(1).str.startswith('SE_A00002')]
# Out:
#       Total Population Population Density (Per Sq. Mile)   Area (Land)
#          SE_A00002_001                     SE_A00002_002 SE_A00002_003
# 0                17599                        273.498500     64.347708
# 1                39209                       1280.782000     30.613331
# 2                50135                       1585.837000     31.614216
# 3                 6304                        148.998700     42.309101
# 4                27590                        768.185800     35.915790
# ...                ...                               ...           ...
# 33115                0                          0.000000     13.875555
# 33116              901                         16.148970     55.793031
# 33117             1684                         12.680840    132.798787
# 33118               59                          0.259136    227.679893
# 33119             2455                          1.135725   2161.614908
#
# [33120 rows x 3 columns]
