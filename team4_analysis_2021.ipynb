# %% [markdown]
# # Imports

# %%
#pip install pgeocode

# %%
import numpy as np
import pandas as pd
import pgeocode
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2021

# %% [markdown]
# # Dataset
# ### CSV file needs some trimming before using it here. Columns not used and empty columns are removed manually

# %%
data21 = pd.read_csv("C:\\Users\\ARU PC\\Documents\\GitHub\\Data\\2021_trimmed.csv")

# %%
data21.head()
# Out:
#    Geo_QName  SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A00003_001  \
# 0       1001          16088      1424.6630      11.292497      12.114230
# 1       1002          27323       513.0521      53.255802      54.908740
# 2       1003          13711     17050.8700       0.804123       0.809529
# 3       1005           4947       114.5428      43.189077      43.446380
# 4       1007          15304       278.9168      54.869406      57.547950
#
#    SE_A00003_002  SE_A00003_003  SE_A02001_001  SE_A02001_002  SE_A02001_003  \
# 0      11.292500       0.821730          16088           7996           8092
# 1      53.255800       1.652938          27323          13344          13979
# 2       0.804123       0.005406          13711           6666           7045
# 3      43.189080       0.257308           4947           2249           2698
# 4      54.869410       2.678543          15304           7668           7636
#
#    ...  SE_A10065_001  SE_A10065_002  SE_A10066_001  SE_A10066_002  \
# 0  ...           2526            783           6791           2195
# 1  ...           3349            888           9985           3164
# 2  ...              0              0             15              0
# 3  ...            750            227           1761            250
# 4  ...           2960            414           5917           1202
#
#    SE_A10066_003  SE_A10066_004  SE_A10066_005  SE_A10066_006  SE_A10066_007  \
# 0           2496            947            750            314             62
# 1           2675           2074           1502            436             97
# 2             15              0              0              0              0
# 3            785            368            233            109              0
# 4           2312            818            959            502            124
#
#    SE_A10066_008
# 0             27
# 1             37
# 2              0
# 3             16
# 4              0
#
# [5 rows x 2186 columns]

# %% [markdown]
# # Working dataset copy

# %%
df = data21.copy()

# %%
df.head()
# Out:
#    Geo_QName  SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A00003_001  \
# 0       1001          16088      1424.6630      11.292497      12.114230
# 1       1002          27323       513.0521      53.255802      54.908740
# 2       1003          13711     17050.8700       0.804123       0.809529
# 3       1005           4947       114.5428      43.189077      43.446380
# 4       1007          15304       278.9168      54.869406      57.547950
#
#    SE_A00003_002  SE_A00003_003  SE_A02001_001  SE_A02001_002  SE_A02001_003  \
# 0      11.292500       0.821730          16088           7996           8092
# 1      53.255800       1.652938          27323          13344          13979
# 2       0.804123       0.005406          13711           6666           7045
# 3      43.189080       0.257308           4947           2249           2698
# 4      54.869410       2.678543          15304           7668           7636
#
#    ...  SE_A10065_001  SE_A10065_002  SE_A10066_001  SE_A10066_002  \
# 0  ...           2526            783           6791           2195
# 1  ...           3349            888           9985           3164
# 2  ...              0              0             15              0
# 3  ...            750            227           1761            250
# 4  ...           2960            414           5917           1202
#
#    SE_A10066_003  SE_A10066_004  SE_A10066_005  SE_A10066_006  SE_A10066_007  \
# 0           2496            947            750            314             62
# 1           2675           2074           1502            436             97
# 2             15              0              0              0              0
# 3            785            368            233            109              0
# 4           2312            818            959            502            124
#
#    SE_A10066_008
# 0             27
# 1             37
# 2              0
# 3             16
# 4              0
#
# [5 rows x 2186 columns]

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# ## Extract zip codes

# %%
#df.insert(0, 'zip_code', df[('Area Name', 'Geo_NAME')].astype(str).str[4:])
#df.drop('Area Name', level = 0, axis =1, inplace=True)

# %%
df.rename(columns={'Geo_QName': 'zip_code'}, inplace=True)

# %%
df = df.loc[pd.to_numeric(df.zip_code).between(10000,20000)] # Filtering rows to limit the data we work on. Selecting group of states starting with 1

# %%
df.set_index('zip_code', inplace=True)

# %%
df.shape
# Out:
# (3726, 2185)

# %%
df.head()
# Out:
#           SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A00003_001  \
# zip_code
# 10001             26966       43227.06       0.623822       0.623822
# 10002             76807       93406.05       0.822291       0.822291
# 10003             54447       95234.96       0.571712       0.571712
# 10004              4795       10525.12       0.455577       0.455577
# 10005              8637      118529.50       0.072868       0.072868
#
#           SE_A00003_002  SE_A00003_003  SE_A02001_001  SE_A02001_002  \
# zip_code
# 10001          0.623822            0.0          26966          12570
# 10002          0.822291            0.0          76807          38640
# 10003          0.571712            0.0          54447          27219
# 10004          0.455577            0.0           4795           2539
# 10005          0.072868            0.0           8637           3880
#
#           SE_A02001_003  SE_A02002_001  ...  SE_A10065_001  SE_A10065_002  \
# zip_code                                ...
# 10001             14396          26966  ...           2571            877
# 10002             38167          76807  ...           8532           4424
# 10003             27228          54447  ...           3310            522
# 10004              2256           4795  ...            989             36
# 10005              4757           8637  ...            989            178
#
#           SE_A10066_001  SE_A10066_002  SE_A10066_003  SE_A10066_004  \
# zip_code
# 10001             14273           7966           4145           1270
# 10002             34737          15261          11054           4567
# 10003             25181          13422           8489           1924
# 10004              2113            772            635            384
# 10005              4782           2515           1530            264
#
#           SE_A10066_005  SE_A10066_006  SE_A10066_007  SE_A10066_008
# zip_code
# 10001               777            115              0              0
# 10002              2761            716            206            172
# 10003              1219            113              8              6
# 10004               266             56              0              0
# 10005               473              0              0              0
#
# [5 rows x 2185 columns]

# %% [markdown]
# ### Extracting only the tables required for the analysis from the dataset

# %%
table_names = ['SE_B13004', 'SE_B18002', 'SE_A03001', 'SE_A13007', 'SE_A14028','SE_A14024_', 'SE_B12001', 'SE_A12003', 'SE_A12004', 'SE_A17005', 'SE_A17009', 'SE_A20001', 'SE_A00002','SE_A10036','SE_A18009']
matching_columns = [col for col in df.columns if col.startswith(tuple(table_names))]
df = df.loc[:, df.columns.isin(matching_columns)]

# %%
# Check for missing values
df = df.dropna() # Drop rows with missing values

# %%
df.head()
# Out:
#           SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A03001_001  \
# zip_code
# 10001             26966       43227.06       0.623822          26966
# 10002             76807       93406.05       0.822291          76807
# 10003             54447       95234.96       0.571712          54447
# 10004              4795       10525.12       0.455577           4795
# 10005              8637      118529.50       0.072868           8637
#
#           SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  \
# zip_code
# 10001             16963           2117             40           4527
# 10002             24687           6453            624          30288
# 10003             38481           2823            148           9110
# 10004              2758            162              0           1593
# 10005              6496            147              0           1180
#
#           SE_A03001_006  SE_A03001_007  ...  SE_A13007_002  SE_A13007_003  \
# zip_code                                ...
# 10001                50           1091  ...           2841            786
# 10002                19           8856  ...          16542           3249
# 10003                45            873  ...           4755           1086
# 10004                 0             20  ...            113             19
# 10005                 0            279  ...            303            267
#
#           SE_A13007_004  SE_A13007_005  SE_A13007_006  SE_A13007_007  \
# zip_code
# 10001               624            162           2055          20284
# 10002              2465            784          13293          50191
# 10003               654            432           3669          37018
# 10004                18              1             94           3697
# 10005               143            124             36           7365
#
#           SE_A13007_008  SE_A13007_009  SE_A13007_010  SE_A13007_011
# zip_code
# 10001             16773          16266            507           3511
# 10002             33060          31112           1948          17131
# 10003             30132          29397            735           6886
# 10004              3245           3193             52            452
# 10005              6970           6862            108            395
#
# [5 rows x 80 columns]

# %%
df.shape
# Out:
# (2809, 80)

# %% [markdown]
# ## Processing dataset column wise

# %% [markdown]
# ### Processing Y variable
# The number of families for each zip code are available for poverty ratios less than 1, between 1 and 2 and more than 2.
# All the families with ratio under 2 are considered to be 'poor' or 'struggling' and over 2 are considered to be ok.
#
# Based on this information, we convert this information into one column which has values 0 or 1
# 0 - if more than 50% of families in the zip code have a ratio over 2 ('ok')
# 1 - if 50% or more of families in the zip code are having ratio under 2 ('struggling')

# %%
df.loc[:, df.columns.str.startswith('SE_B13004')]
# Out:
#           SE_B13004_001  SE_B13004_002  SE_B13004_003  SE_B13004_004  \
# zip_code
# 10001             26023           3557           1993           5550
# 10002             76047          20554          16375          36929
# 10003             44965           4872           2478           7350
# 10004              4794            141             79            220
# 10005              8637            303             95            398
# ...                 ...            ...            ...            ...
# 19971             14101           1130            968           2098
# 19973             25302           4173           4551           8724
# 19975              9609            667           1229           1896
# 19977             22937           2402           2145           4547
# 19979               628             44            112            156
#
#           SE_B13004_005
# zip_code
# 10001             20473
# 10002             39118
# 10003             37615
# 10004              4574
# 10005              8239
# ...                 ...
# 19971             12003
# 19973             16578
# 19975              7713
# 19977             18390
# 19979               472
#
# [2809 rows x 5 columns]

# %%
df['underPoverty'] = np.where(df[('SE_B13004_005')].div(df[('SE_B13004_001')]) < 0.5,1,0) 
df = df.loc[: ,~df.columns.str.startswith('SE_B13004')] # Drop the columns from the table after processing

# %%
len(df.loc[df['underPoverty'] == 1]) # There are 148 zip codes in region 1 which have more than 50% of families that are poor or struggling
# Out:
# 148

# %% [markdown]
# # Income

# %% [markdown]
# ### Below Poverty line
# Poverty Status in the Past 12 Months based on income level. Proportion of population having income below poverty level

# %%
df.loc[:, df.columns.str.startswith('SE_A13007')]
# Out:
#           SE_A13007_001  SE_A13007_002  SE_A13007_003  SE_A13007_004  \
# zip_code
# 10001             23125           2841            786            624
# 10002             66733          16542           3249           2465
# 10003             41773           4755           1086            654
# 10004              3810            113             19             18
# 10005              7668            303            267            143
# ...                 ...            ...            ...            ...
# 19971             13271           1020            386            231
# 19973             20442           3034           1511           1092
# 19975              8676            590            260            189
# 19977             17668           1700            781            673
# 19979               536             44             38             29
#
#           SE_A13007_005  SE_A13007_006  SE_A13007_007  SE_A13007_008  \
# zip_code
# 10001               162           2055          20284          16773
# 10002               784          13293          50191          33060
# 10003               432           3669          37018          30132
# 10004                 1             94           3697           3245
# 10005               124             36           7365           6970
# ...                 ...            ...            ...            ...
# 19971               155            634          12251           6359
# 19973               419           1523          17408          11754
# 19975                71            330           8086           4121
# 19977               108            919          15968          10835
# 19979                 9              6            492            373
#
#           SE_A13007_009  SE_A13007_010  SE_A13007_011
# zip_code
# 10001             16266            507           3511
# 10002             31112           1948          17131
# 10003             29397            735           6886
# 10004              3193             52            452
# 10005              6862            108            395
# ...                 ...            ...            ...
# 19971              6224            135           5892
# 19973             11215            539           5654
# 19975              3896            225           3965
# 19977             10378            457           5133
# 19979               368              5            119
#
# [2809 rows x 11 columns]

# %%
df['incomeBelowPovertyLevelProportion'] = ((df[('SE_A13007_002')].values) /(df[('SE_A13007_001')]))
df.incomeBelowPovertyLevelProportion.describe()
df = df.loc[: ,~df.columns.str.startswith('SE_A13007')] # Drop the columns from the table after processing

# %% [markdown]
# ## Per Capita

# %%
df.loc[:, 'incomePerCapita'] = df.loc[: ,df.columns.str.startswith('SE_A14024')].values
df = df.loc[: ,~df.columns.str.startswith('SE_A14024')] # Drop the columns from the table after processing
df.incomePerCapita.describe()
# Out:
# count      2809.000000
# mean      37809.395158
# std       17445.114322
# min        5116.000000
# 25%       28070.000000
# 50%       33322.000000
# 75%       41504.000000
# max      190168.000000
# Name: incomePerCapita, dtype: float64

# %% [markdown]
# ## GiniIndex

# %%
df.loc[:, 'incomeGiniIndex'] = df.loc[: ,df.columns.str.startswith('SE_A14028_001')]

# %%
df = df.loc[: ,~df.columns.str.startswith('SE_A14028')] # Drop the columns from the table after processing

# %%
df.incomeGiniIndex.describe()
# Out:
# count    2809.000000
# mean        0.421469
# std         0.059241
# min         0.156100
# 25%         0.384100
# 50%         0.416900
# 75%         0.455200
# max         0.760200
# Name: incomeGiniIndex, dtype: float64

# %%
df.head()
# Out:
#           SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A03001_001  \
# zip_code
# 10001             26966       43227.06       0.623822          26966
# 10002             76807       93406.05       0.822291          76807
# 10003             54447       95234.96       0.571712          54447
# 10004              4795       10525.12       0.455577           4795
# 10005              8637      118529.50       0.072868           8637
#
#           SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  \
# zip_code
# 10001             16963           2117             40           4527
# 10002             24687           6453            624          30288
# 10003             38481           2823            148           9110
# 10004              2758            162              0           1593
# 10005              6496            147              0           1180
#
#           SE_A03001_006  SE_A03001_007  ...  SE_A18009_001  SE_A20001_001  \
# zip_code                                ...
# 10001                50           1091  ...         2269.0          26966
# 10002                19           8856  ...         1047.0          76361
# 10003                45            873  ...         2478.0          54273
# 10004                 0             20  ...         3501.0           4795
# 10005                 0            279  ...         3501.0           8637
#
#           SE_A20001_002  SE_A20001_003  SE_A20001_004  SE_A20001_005  \
# zip_code
# 10001               800          26166           7241          21172
# 10002              4255          72106          41115          35755
# 10003              1636          52637           9993          46799
# 10004                51           4744            243           4607
# 10005                83           8554            469           8153
#
#           underPoverty  incomeBelowPovertyLevelProportion  incomePerCapita  \
# zip_code
# 10001                0                           0.122854          94177.0
# 10002                0                           0.247883          37557.0
# 10003                0                           0.113830         106585.0
# 10004                0                           0.029659         147878.0
# 10005                0                           0.039515         128970.0
#
#           incomeGiniIndex
# zip_code
# 10001              0.5524
# 10002              0.5922
# 10003              0.5532
# 10004              0.4566
# 10005              0.3579
#
# [5 rows x 66 columns]

# %%
df.shape
# Out:
# (2809, 66)

# %%
df.dropna()
# Out:
#           SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A03001_001  \
# zip_code
# 10001             26966     43227.0600       0.623822          26966
# 10002             76807     93406.0500       0.822291          76807
# 10003             54447     95234.9600       0.571712          54447
# 10004              4795     10525.1200       0.455577           4795
# 10005              8637    118529.5000       0.072868           8637
# ...                 ...            ...            ...            ...
# 19971             14132       786.7947      17.961482          14132
# 19973             25619       305.0022      83.996108          25619
# 19975              9610       376.3289      25.536177           9610
# 19977             25907       311.7339      83.106127          25907
# 19979               641       195.2395       3.283146            641
#
#           SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  \
# zip_code
# 10001             16963           2117             40           4527
# 10002             24687           6453            624          30288
# 10003             38481           2823            148           9110
# 10004              2758            162              0           1593
# 10005              6496            147              0           1180
# ...                 ...            ...            ...            ...
# 19971             12344            927              4            255
# 19973             16798           5843             30            324
# 19975              8773            233             16             28
# 19977             15120           8375             20            224
# 19979               624              0              0              0
#
#           SE_A03001_006  SE_A03001_007  ...  SE_A18009_001  SE_A20001_001  \
# zip_code                                ...
# 10001                50           1091  ...         2269.0          26966
# 10002                19           8856  ...         1047.0          76361
# 10003                45            873  ...         2478.0          54273
# 10004                 0             20  ...         3501.0           4795
# 10005                 0            279  ...         3501.0           8637
# ...                 ...            ...  ...            ...            ...
# 19971                 0            185  ...         1389.0          14105
# 19973                 0            904  ...          918.0          25368
# 19975                65            151  ...         1123.0           9583
# 19977                 0            200  ...         1310.0          22637
# 19979                 0              0  ...         1276.0            641
#
#           SE_A20001_002  SE_A20001_003  SE_A20001_004  SE_A20001_005  \
# zip_code
# 10001               800          26166           7241          21172
# 10002              4255          72106          41115          35755
# 10003              1636          52637           9993          46799
# 10004                51           4744            243           4607
# 10005                83           8554            469           8153
# ...                 ...            ...            ...            ...
# 19971               353          13752           7024          10808
# 19973              1844          23524          11688          16004
# 19975               719           8864           4775           6751
# 19977              1927          20710           8743          15621
# 19979                19            622            163            542
#
#           underPoverty  incomeBelowPovertyLevelProportion  incomePerCapita  \
# zip_code
# 10001                0                           0.122854          94177.0
# 10002                0                           0.247883          37557.0
# 10003                0                           0.113830         106585.0
# 10004                0                           0.029659         147878.0
# 10005                0                           0.039515         128970.0
# ...                ...                                ...              ...
# 19971                0                           0.076859          71808.0
# 19973                0                           0.148420          30349.0
# 19975                0                           0.068004          46887.0
# 19977                0                           0.096219          31613.0
# 19979                0                           0.082090          35973.0
#
#           incomeGiniIndex
# zip_code
# 10001              0.5524
# 10002              0.5922
# 10003              0.5532
# 10004              0.4566
# 10005              0.3579
# ...                   ...
# 19971              0.5314
# 19973              0.4386
# 19975              0.4447
# 19977              0.4006
# 19979              0.2933
#
# [2809 rows x 66 columns]

# %% [markdown]
# ## Race, Population

# %%
df.head(2)
# Out:
#           SE_A00002_001  SE_A00002_002  SE_A00002_003  SE_A03001_001  \
# zip_code
# 10001             26966       43227.06       0.623822          26966
# 10002             76807       93406.05       0.822291          76807
#
#           SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  \
# zip_code
# 10001             16963           2117             40           4527
# 10002             24687           6453            624          30288
#
#           SE_A03001_006  SE_A03001_007  ...  SE_A18009_001  SE_A20001_001  \
# zip_code                                ...
# 10001                50           1091  ...         2269.0          26966
# 10002                19           8856  ...         1047.0          76361
#
#           SE_A20001_002  SE_A20001_003  SE_A20001_004  SE_A20001_005  \
# zip_code
# 10001               800          26166           7241          21172
# 10002              4255          72106          41115          35755
#
#           underPoverty  incomeBelowPovertyLevelProportion  incomePerCapita  \
# zip_code
# 10001                0                           0.122854          94177.0
# 10002                0                           0.247883          37557.0
#
#           incomeGiniIndex
# zip_code
# 10001              0.5524
# 10002              0.5922
#
# [2 rows x 66 columns]

# %%
df.loc[:, 'popDensity'] = df.loc[:,('SE_A00002_002')].values 
df = df.loc[: ,~df.columns.str.startswith('SE_A00001')] # Drop the columns from the table after processing
df.popDensity.describe()
# Out:
# count      2809.000000
# mean       4191.867054
# std       13734.303928
# min           0.834195
# 25%          66.714400
# 50%         271.805600
# 75%        1844.599000
# max      151475.800000
# Name: popDensity, dtype: float64

# %%
df.drop(['SE_A00002_001','SE_A00002_003', ], axis = 1, inplace = True) #dropping Total population and population density

# %% [markdown]
# ### White Majority
# We check if white-only population is the majority in a zip code
# Primarily non-white areas might be experiencing higher levels of poverty.
# 0 - if less than 50% of population in the zip code are white
# 1 - if more than 50% of families in the zip code are non-white

# %%
df.drop(df.loc[df.loc[:,df.columns.str.startswith('SE_A03001_001')].isin([0]).any(axis = 1)].index, inplace = True) #dropping any null values
df.loc[:, 'whiteMajority'] = ((df.loc[:,'SE_A03001_002'].values) / (df.loc[:,'SE_A03001_001'].values)) # If the proportion of white alone population is more than 50% we set this binary variable to 1
df = df.loc[: ,~df.columns.str.startswith('SE_A03001')] # Drop the columns from the table after processing
df['whiteMajority'].describe()
# Out:
# count    2809.000000
# mean        0.843544
# std         0.195704
# min         0.019053
# 25%         0.803446
# 50%         0.922897
# 75%         0.965156
# max         1.000000
# Name: whiteMajority, dtype: float64

# %% [markdown]
# ## Education

# %% [markdown]
# ### Highest degree attainment

# %%
df.loc[: ,df.columns.str.startswith('SE_B12001_')]
# Out:
#           SE_B12001_001  SE_B12001_002  SE_B12001_003  SE_B12001_004
# zip_code
# 10001             21296           1538           4182          15576
# 10002             60747          19576          19073          22098
# 10003             37589           1360           5267          30962
# 10004              3624             13            112           3499
# 10005              6829              6            494           6329
# ...                 ...            ...            ...            ...
# 19971             12623            474           5611           6538
# 19973             17963           2481          12269           3213
# 19975              8079            719           4325           3035
# 19977             18937           1670          13003           4264
# 19979               510             38            389             83
#
# [2809 rows x 4 columns]

# %%
df = df.loc[df['SE_B12001_001'] != 0] # Some of the zip codes have 0. To avoid RuntimeWarning we drop these rows

# %%
df.loc[:, 'eduHsOrLessProportion'] = ((df.loc[:,('SE_B12001_002')].values) / (df.loc[:,('SE_B12001_001')].values)) # Proportion of 25yo and over with less than high school education
df.loc[:, 'eduHsProportion'] = ((df.loc[:,('SE_B12001_003')].values) / (df.loc[:,('SE_B12001_001')].values)) # Proportion of 25yo and over with less than high school education
df.loc[:, 'eduBachOrBetterProportion'] = ((df.loc[:,('SE_B12001_004')].values) / (df.loc[:,('SE_B12001_001')].values)) # Proportion of 25yo and over with less than high school education
df = df.loc[: ,~df.columns.str.startswith('SE_B12001_')] # Drop the columns from the table after processing
print(df.eduHsOrLessProportion.describe())
print(df.eduHsProportion.describe())
print(df.eduBachOrBetterProportion.describe())
# Out:
# count    2809.000000
# mean        0.096295
# std         0.063946
# min         0.000000
# 25%         0.053577
# 50%         0.082806
# 75%         0.120284
# max         0.528090
# Name: eduHsOrLessProportion, dtype: float64
# count    2809.000000
# mean        0.611586
# std         0.148978
# min         0.030905
# 25%         0.536492
# 50%         0.645638
# 75%         0.716269
# max         1.000000
# Name: eduHsProportion, dtype: float64
# count    2809.000000
# mean        0.292119
# std         0.167296
# min         0.000000
# 25%         0.172269
# 50%         0.247191
# 75%         0.374343
# max         0.965508
# Name: eduBachOrBetterProportion, dtype: float64

# %% [markdown]
# ### School Enrollment

# %%
df.loc[: ,df.columns.str.startswith('SE_A12004')] # Drop the columns from the table after processing
# Out:
#           SE_A12004_001  SE_A12004_002  SE_A12004_003
# zip_code
# 10001             26310           4375          21935
# 10002             75343          13024          62319
# 10003             53328          15093          38235
# 10004              4326            571           3755
# 10005              8292            839           7453
# ...                 ...            ...            ...
# 19971             13941           1181          12760
# 19973             24657           5322          19335
# 19975              9506           1223           8283
# 19977             25049           5658          19391
# 19979               631            162            469
#
# [2809 rows x 3 columns]

# %%
df.loc[:, 'eduEnrollmentProportion'] = ((df.loc[:,('SE_A12004_002')].values) / (df.loc[:,('SE_A12004_001')].values)) # If the proportion of 3yo and over enrolled in school is more than 50% we set this binary variable to 1
df = df.loc[: ,~df.columns.str.startswith('SE_A12004')] # Drop the columns from the table after processing
df['eduEnrollmentProportion'].describe()
# Out:
# count    2809.000000
# mean        0.217488
# std         0.064958
# min         0.000000
# 25%         0.182594
# 50%         0.214505
# 75%         0.248044
# max         0.876300
# Name: eduEnrollmentProportion, dtype: float64

# %% [markdown]
# ### School Dropout rate

# %%
df = df.loc[df['SE_A12003_001'] != 0] # Some of the zip codes have 0 civilian population. To avoid RuntimeWarning we drop these rows

# %%
df.loc[:, 'eduDropoutProportion'] = ((df.loc[:,('SE_A12003_002')].values) / (df.loc[:,('SE_A12003_001')].values)) # If the proportion of late teens dropped out from school is more than 50% we set this binary variable to 1
df = df.loc[: ,~df.columns.str.startswith('SE_A12003')] # Drop the columns from the table after processing
df.eduDropoutProportion.describe()
# Out:
# count    2762.000000
# mean        0.055753
# std         0.113325
# min         0.000000
# 25%         0.000000
# 50%         0.011113
# 75%         0.058097
# max         1.000000
# Name: eduDropoutProportion, dtype: float64

# %% [markdown]
# # Employement

# %% [markdown]
# ## Proportion of labor force employed

# %%
df.loc[: ,df.columns.str.startswith('SE_A17005')]
# Out:
#           SE_A17005_001  SE_A17005_002  SE_A17005_003  SE_A17005A_001  \
# zip_code
# 10001             17828          17098            730            9085
# 10002             36431          33689           2742           18809
# 10003             34455          32693           1762           17586
# 10004              3264           3211             53            1913
# 10005              7237           7005            232            3586
# ...                 ...            ...            ...             ...
# 19971              6745           6455            290            3383
# 19973             13265          12307            958            6751
# 19975              4381           4085            296            2263
# 19977             11616          11051            565            5213
# 19979               411            397             14             243
#
#           SE_A17005A_002  SE_A17005A_003  SE_A17005B_001  SE_A17005B_002  \
# zip_code
# 10001               8672             413            8743            8426
# 10002              17437            1372           17622           16252
# 10003              16925             661           16869           15768
# 10004               1912               1            1351            1299
# 10005               3459             127            3651            3546
# ...                  ...             ...             ...             ...
# 19971               3295              88            3362            3160
# 19973               6130             621            6514            6177
# 19975               2096             167            2118            1989
# 19977               4876             337            6403            6175
# 19979                243               0             168             154
#
#           SE_A17005B_003
# zip_code
# 10001                317
# 10002               1370
# 10003               1101
# 10004                 52
# 10005                105
# ...                  ...
# 19971                202
# 19973                337
# 19975                129
# 19977                228
# 19979                 14
#
# [2762 rows x 9 columns]

# %%
df = df.loc[df.loc[:,('SE_A17005_001')] != 0] # Some of the zip codes have 0 civilian population. To avoid RuntimeWarning we drop these rows

# %%
# df.loc[:, 'employedMajority'] = np.where((df.loc[:,('Civilian Population in Labor Force 16 Years and Over: Employed' ,'SE_A17005_002')].values) / (df.loc[:,('Civilian Population in Labor Force 16 Years and Over:','SE_A17005_001')].values) > 0.5,1,0) # If the proportion of late teens dropped out from school is more than 50% we set this binary variable to 1
df.loc[:, 'employedProportion'] = ((df.loc[:,('SE_A17005_002')].values) / (df.loc[:,('SE_A17005_001')].values))
df = df.loc[: ,~df.columns.str.startswith('SE_A17005')] # Drop the columns from the table after processing
df.employedProportion.describe()
# Out:
# count    2762.000000
# mean        0.945659
# std         0.033943
# min         0.672566
# 25%         0.931652
# 50%         0.951351
# 75%         0.967480
# max         1.000000
# Name: employedProportion, dtype: float64

# %% [markdown]
# ### Employment by sector

# %%
df.loc[: ,df.columns.str.startswith('SE_A17009')]
# Out:
#           SE_A17009_001  SE_A17009_002  SE_A17009_003  SE_A17009_004  \
# zip_code
# 10001             17098          12421           1028           2287
# 10002             33689          23553           3459           3752
# 10003             32693          22385           1790           4263
# 10004              3211           2115            255            632
# 10005              7005           5713            482            408
# ...                 ...            ...            ...            ...
# 19971              6455           3583            850           1222
# 19973             12307           8098           1598           1510
# 19975              4085           2645            692            430
# 19977             11051           6900           2663            741
# 19979               397            221            133             33
#
#           SE_A17009_005  SE_A17009_006
# zip_code
# 10001              1362              0
# 10002              2776            149
# 10003              4160             95
# 10004               173             36
# 10005               402              0
# ...                 ...            ...
# 19971               800              0
# 19973              1046             55
# 19975               310              8
# 19977               747              0
# 19979                10              0
#
# [2762 rows x 6 columns]

# %%
df.loc[:, 'employedPvtSecProportion'] = ((df.loc[:,('SE_A17009_002')].values) / (df.loc[:,('SE_A17009_001')].values))
df.loc[:, 'employedPubSecProportion'] = ((df.loc[:,('SE_A17009_003')].values) / (df.loc[:,('SE_A17009_001')].values))
df.loc[:, 'employedSelfEmpProportion'] = ((df.loc[:,('SE_A17009_004')].values) / (df.loc[:,('SE_A17009_001')].values))
df.loc[:, 'employedPvtNonProProportion'] = ((df.loc[:,('SE_A17009_005')].values) / (df.loc[:,('SE_A17009_001')].values))
df.loc[:, 'employedUnpaidFamProportion'] = ((df.loc[:,('SE_A17009_006')].values) / (df.loc[:,('SE_A17009_001')].values))
df = df.loc[: ,~df.columns.str.startswith('SE_A17009')] # Drop the columns from the table after processing

# %%
df.loc[:, 'employedUnpaidFamProportion']
# Out:
# zip_code
# 10001    0.000000
# 10002    0.004423
# 10003    0.002906
# 10004    0.011211
# 10005    0.000000
#            ...
# 19971    0.000000
# 19973    0.004469
# 19975    0.001958
# 19977    0.000000
# 19979    0.000000
# Name: employedUnpaidFamProportion, Length: 2762, dtype: float64

# %% [markdown]
# ## Health

# %%
df.loc[: ,df.columns.str.startswith('SE_A20001')]
# Out:
#           SE_A20001_001  SE_A20001_002  SE_A20001_003  SE_A20001_004  \
# zip_code
# 10001             26966            800          26166           7241
# 10002             76361           4255          72106          41115
# 10003             54273           1636          52637           9993
# 10004              4795             51           4744            243
# 10005              8637             83           8554            469
# ...                 ...            ...            ...            ...
# 19971             14105            353          13752           7024
# 19973             25368           1844          23524          11688
# 19975              9583            719           8864           4775
# 19977             22637           1927          20710           8743
# 19979               641             19            622            163
#
#           SE_A20001_005
# zip_code
# 10001             21172
# 10002             35755
# 10003             46799
# 10004              4607
# 10005              8153
# ...                 ...
# 19971             10808
# 19973             16004
# 19975              6751
# 19977             15621
# 19979               542
#
# [2762 rows x 5 columns]

# %%
df = df.loc[df.loc[:,('SE_A20001_001')] != 0] # Some of the zip codes have 0. To avoid RuntimeWarning we drop these rows
df.loc[:, 'insuredProportion'] = ((df.loc[:,('SE_A20001_003')].values) / (df.loc[:,('SE_A20001_001')].values))
df = df.loc[: ,~df.columns.str.startswith('SE_A20001')] # Drop the columns from the table after processing
df.insuredProportion.describe()
# Out:
# count    2762.000000
# mean        0.944078
# std         0.054047
# min         0.393746
# 25%         0.933320
# 50%         0.956894
# 75%         0.973802
# max         1.000000
# Name: insuredProportion, dtype: float64

# %%
df.shape
# Out:
# (2762, 24)

# %% [markdown]
# # Housing

# %% [markdown]
# ### Proportion of renters spending more than 30% of income on rent
#
# Here, we are only concerned with Renter-Occupied Housing Units who are paying the rent which is more than 30% of their income

# %%
df.loc[:, df.columns.str.startswith('SE_B18002')]
# Out:
#           SE_B18002_001  SE_B18002_002  SE_B18002_003
# zip_code
# 10001             10493           2366           1708
# 10002             28887           7294           7312
# 10003             15936           3197           3370
# 10004              1249            215            188
# 10005              3987            877            512
# ...                 ...            ...            ...
# 19971               942            182            420
# 19973              2365            549            636
# 19975               632            248             73
# 19977              1677            409            409
# 19979                51              0              0
#
# [2762 rows x 3 columns]

# %%
df = df.loc[df.loc[:, ('SE_B18002_001')] != 0] # Remove observations with 0 to avoid error while dividing
df.loc[:, 'housingRentMoreThan30pcProportion'] = ((df.loc[:,('SE_B18002_002')].values + df.loc[:,('SE_B18002_003')].values ) / (df.loc[:,('SE_B18002_001')].values))

# %%
df.head()
# Out:
#           SE_A00002_002  SE_A10036_001  SE_B18002_001  SE_B18002_002  \
# zip_code
# 10001          43227.06       467800.0          10493           2366
# 10002          93406.05       719500.0          28887           7294
# 10003          95234.96       972900.0          15936           3197
# 10004          10525.12      1722600.0           1249            215
# 10005         118529.50      1237900.0           3987            877
#
#           SE_B18002_003  SE_A18009_001  underPoverty  \
# zip_code
# 10001              1708         2269.0             0
# 10002              7312         1047.0             0
# 10003              3370         2478.0             0
# 10004               188         3501.0             0
# 10005               512         3501.0             0
#
#           incomeBelowPovertyLevelProportion  incomePerCapita  incomeGiniIndex  \
# zip_code
# 10001                              0.122854          94177.0           0.5524
# 10002                              0.247883          37557.0           0.5922
# 10003                              0.113830         106585.0           0.5532
# 10004                              0.029659         147878.0           0.4566
# 10005                              0.039515         128970.0           0.3579
#
#           ...  eduEnrollmentProportion  eduDropoutProportion  \
# zip_code  ...
# 10001     ...                 0.166287              0.000000
# 10002     ...                 0.172863              0.015896
# 10003     ...                 0.283022              0.002343
# 10004     ...                 0.131993              0.000000
# 10005     ...                 0.101182              0.000000
#
#           employedProportion  employedPvtSecProportion  \
# zip_code
# 10001               0.959053                  0.726459
# 10002               0.924734                  0.699130
# 10003               0.948861                  0.684703
# 10004               0.983762                  0.658673
# 10005               0.967943                  0.815560
#
#           employedPubSecProportion  employedSelfEmpProportion  \
# zip_code
# 10001                     0.060124                   0.133758
# 10002                     0.102674                   0.111372
# 10003                     0.054752                   0.130395
# 10004                     0.079415                   0.196823
# 10005                     0.068808                   0.058244
#
#           employedPvtNonProProportion  employedUnpaidFamProportion  \
# zip_code
# 10001                        0.079658                     0.000000
# 10002                        0.082401                     0.004423
# 10003                        0.127244                     0.002906
# 10004                        0.053877                     0.011211
# 10005                        0.057388                     0.000000
#
#           insuredProportion  housingRentMoreThan30pcProportion
# zip_code
# 10001              0.970333                           0.388259
# 10002              0.944278                           0.505625
# 10003              0.969856                           0.412086
# 10004              0.989364                           0.322658
# 10005              0.990390                           0.348382
#
# [5 rows x 25 columns]

# %%
df = df.loc[: ,~df.columns.str.startswith('SE_B18002')] # Drop the columns from the table after processing

# %%
df.head()
# Out:
#           SE_A00002_002  SE_A10036_001  SE_A18009_001  underPoverty  \
# zip_code
# 10001          43227.06       467800.0         2269.0             0
# 10002          93406.05       719500.0         1047.0             0
# 10003          95234.96       972900.0         2478.0             0
# 10004          10525.12      1722600.0         3501.0             0
# 10005         118529.50      1237900.0         3501.0             0
#
#           incomeBelowPovertyLevelProportion  incomePerCapita  incomeGiniIndex  \
# zip_code
# 10001                              0.122854          94177.0           0.5524
# 10002                              0.247883          37557.0           0.5922
# 10003                              0.113830         106585.0           0.5532
# 10004                              0.029659         147878.0           0.4566
# 10005                              0.039515         128970.0           0.3579
#
#           popDensity  whiteMajority  eduHsOrLessProportion  ...  \
# zip_code                                                    ...
# 10001       43227.06       0.629051               0.072220  ...
# 10002       93406.05       0.321416               0.322255  ...
# 10003       95234.96       0.706761               0.036181  ...
# 10004       10525.12       0.575182               0.003587  ...
# 10005      118529.50       0.752113               0.000879  ...
#
#           eduEnrollmentProportion  eduDropoutProportion  employedProportion  \
# zip_code
# 10001                    0.166287              0.000000            0.959053
# 10002                    0.172863              0.015896            0.924734
# 10003                    0.283022              0.002343            0.948861
# 10004                    0.131993              0.000000            0.983762
# 10005                    0.101182              0.000000            0.967943
#
#           employedPvtSecProportion  employedPubSecProportion  \
# zip_code
# 10001                     0.726459                  0.060124
# 10002                     0.699130                  0.102674
# 10003                     0.684703                  0.054752
# 10004                     0.658673                  0.079415
# 10005                     0.815560                  0.068808
#
#           employedSelfEmpProportion  employedPvtNonProProportion  \
# zip_code
# 10001                      0.133758                     0.079658
# 10002                      0.111372                     0.082401
# 10003                      0.130395                     0.127244
# 10004                      0.196823                     0.053877
# 10005                      0.058244                     0.057388
#
#           employedUnpaidFamProportion  insuredProportion  \
# zip_code
# 10001                        0.000000           0.970333
# 10002                        0.004423           0.944278
# 10003                        0.002906           0.969856
# 10004                        0.011211           0.989364
# 10005                        0.000000           0.990390
#
#           housingRentMoreThan30pcProportion
# zip_code
# 10001                              0.388259
# 10002                              0.505625
# 10003                              0.412086
# 10004                              0.322658
# 10005                              0.348382
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (2762, 22)

# %% [markdown]
# ### Housing Units by Monthly Housing Costs

# %%
df.loc[:, df.columns.str.startswith('SE_A10036')]
# Out:
#           SE_A10036_001
# zip_code
# 10001          467800.0
# 10002          719500.0
# 10003          972900.0
# 10004         1722600.0
# 10005         1237900.0
# ...                 ...
# 19971          435100.0
# 19973          211500.0
# 19975          356000.0
# 19977          247200.0
# 19979          205400.0
#
# [2762 rows x 1 columns]

# %%
df.loc[:, 'housingMedianValue'] = ((df.loc[:,('SE_A10036_001')].values))
# Out:
# C:\Users\ARU PC\AppData\Local\Temp\ipykernel_8744\3377533607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'housingMedianValue'] = ((df.loc[:,('SE_A10036_001')].values))

# %%
df = df.loc[: ,~df.columns.str.startswith('SE_A10036_')] # Drop the columns from the table after processing

# %%
df.head()
# Out:
#           SE_A00002_002  SE_A18009_001  underPoverty  \
# zip_code
# 10001          43227.06         2269.0             0
# 10002          93406.05         1047.0             0
# 10003          95234.96         2478.0             0
# 10004          10525.12         3501.0             0
# 10005         118529.50         3501.0             0
#
#           incomeBelowPovertyLevelProportion  incomePerCapita  incomeGiniIndex  \
# zip_code
# 10001                              0.122854          94177.0           0.5524
# 10002                              0.247883          37557.0           0.5922
# 10003                              0.113830         106585.0           0.5532
# 10004                              0.029659         147878.0           0.4566
# 10005                              0.039515         128970.0           0.3579
#
#           popDensity  whiteMajority  eduHsOrLessProportion  eduHsProportion  \
# zip_code
# 10001       43227.06       0.629051               0.072220         0.196375
# 10002       93406.05       0.321416               0.322255         0.313974
# 10003       95234.96       0.706761               0.036181         0.140121
# 10004       10525.12       0.575182               0.003587         0.030905
# 10005      118529.50       0.752113               0.000879         0.072339
#
#           ...  eduDropoutProportion  employedProportion  \
# zip_code  ...
# 10001     ...              0.000000            0.959053
# 10002     ...              0.015896            0.924734
# 10003     ...              0.002343            0.948861
# 10004     ...              0.000000            0.983762
# 10005     ...              0.000000            0.967943
#
#           employedPvtSecProportion  employedPubSecProportion  \
# zip_code
# 10001                     0.726459                  0.060124
# 10002                     0.699130                  0.102674
# 10003                     0.684703                  0.054752
# 10004                     0.658673                  0.079415
# 10005                     0.815560                  0.068808
#
#           employedSelfEmpProportion  employedPvtNonProProportion  \
# zip_code
# 10001                      0.133758                     0.079658
# 10002                      0.111372                     0.082401
# 10003                      0.130395                     0.127244
# 10004                      0.196823                     0.053877
# 10005                      0.058244                     0.057388
#
#           employedUnpaidFamProportion  insuredProportion  \
# zip_code
# 10001                        0.000000           0.970333
# 10002                        0.004423           0.944278
# 10003                        0.002906           0.969856
# 10004                        0.011211           0.989364
# 10005                        0.000000           0.990390
#
#           housingRentMoreThan30pcProportion  housingMedianValue
# zip_code
# 10001                              0.388259            467800.0
# 10002                              0.505625            719500.0
# 10003                              0.412086            972900.0
# 10004                              0.322658           1722600.0
# 10005                              0.348382           1237900.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Median Gross Rent

# %%
df.loc[:, df.columns.str.startswith('SE_A18009')]
# Out:
#           SE_A18009_001
# zip_code
# 10001            2269.0
# 10002            1047.0
# 10003            2478.0
# 10004            3501.0
# 10005            3501.0
# ...                 ...
# 19971            1389.0
# 19973             918.0
# 19975            1123.0
# 19977            1310.0
# 19979            1276.0
#
# [2762 rows x 1 columns]

# %%
df.loc[:, 'housingMedianGrossRent'] = ((df.loc[:,('SE_A18009_001')].values))

# %%
df = df.loc[: ,~df.columns.str.startswith('SE_A18009_')] # Drop the columns from the table after processing

# %%
df.shape
# Out:
# (2762, 22)

# %%
df.head()
# Out:
#           SE_A00002_002  underPoverty  incomeBelowPovertyLevelProportion  \
# zip_code
# 10001          43227.06             0                           0.122854
# 10002          93406.05             0                           0.247883
# 10003          95234.96             0                           0.113830
# 10004          10525.12             0                           0.029659
# 10005         118529.50             0                           0.039515
#
#           incomePerCapita  incomeGiniIndex  popDensity  whiteMajority  \
# zip_code
# 10001             94177.0           0.5524    43227.06       0.629051
# 10002             37557.0           0.5922    93406.05       0.321416
# 10003            106585.0           0.5532    95234.96       0.706761
# 10004            147878.0           0.4566    10525.12       0.575182
# 10005            128970.0           0.3579   118529.50       0.752113
#
#           eduHsOrLessProportion  eduHsProportion  eduBachOrBetterProportion  \
# zip_code
# 10001                  0.072220         0.196375                   0.731405
# 10002                  0.322255         0.313974                   0.363771
# 10003                  0.036181         0.140121                   0.823698
# 10004                  0.003587         0.030905                   0.965508
# 10005                  0.000879         0.072339                   0.926783
#
#           ...  employedProportion  employedPvtSecProportion  \
# zip_code  ...
# 10001     ...            0.959053                  0.726459
# 10002     ...            0.924734                  0.699130
# 10003     ...            0.948861                  0.684703
# 10004     ...            0.983762                  0.658673
# 10005     ...            0.967943                  0.815560
#
#           employedPubSecProportion  employedSelfEmpProportion  \
# zip_code
# 10001                     0.060124                   0.133758
# 10002                     0.102674                   0.111372
# 10003                     0.054752                   0.130395
# 10004                     0.079415                   0.196823
# 10005                     0.068808                   0.058244
#
#           employedPvtNonProProportion  employedUnpaidFamProportion  \
# zip_code
# 10001                        0.079658                     0.000000
# 10002                        0.082401                     0.004423
# 10003                        0.127244                     0.002906
# 10004                        0.053877                     0.011211
# 10005                        0.057388                     0.000000
#
#           insuredProportion  housingRentMoreThan30pcProportion  \
# zip_code
# 10001              0.970333                           0.388259
# 10002              0.944278                           0.505625
# 10003              0.969856                           0.412086
# 10004              0.989364                           0.322658
# 10005              0.990390                           0.348382
#
#           housingMedianValue  housingMedianGrossRent
# zip_code
# 10001               467800.0                  2269.0
# 10002               719500.0                  1047.0
# 10003               972900.0                  2478.0
# 10004              1722600.0                  3501.0
# 10005              1237900.0                  3501.0
#
# [5 rows x 22 columns]

# %%
df.drop('SE_A00002_002',axis=1,inplace=True)

# %%
df.head()
# Out:
#           underPoverty  incomeBelowPovertyLevelProportion  incomePerCapita  \
# zip_code
# 10001                0                           0.122854          94177.0
# 10002                0                           0.247883          37557.0
# 10003                0                           0.113830         106585.0
# 10004                0                           0.029659         147878.0
# 10005                0                           0.039515         128970.0
#
#           incomeGiniIndex  popDensity  whiteMajority  eduHsOrLessProportion  \
# zip_code
# 10001              0.5524    43227.06       0.629051               0.072220
# 10002              0.5922    93406.05       0.321416               0.322255
# 10003              0.5532    95234.96       0.706761               0.036181
# 10004              0.4566    10525.12       0.575182               0.003587
# 10005              0.3579   118529.50       0.752113               0.000879
#
#           eduHsProportion  eduBachOrBetterProportion  eduEnrollmentProportion  \
# zip_code
# 10001            0.196375                   0.731405                 0.166287
# 10002            0.313974                   0.363771                 0.172863
# 10003            0.140121                   0.823698                 0.283022
# 10004            0.030905                   0.965508                 0.131993
# 10005            0.072339                   0.926783                 0.101182
#
#           ...  employedProportion  employedPvtSecProportion  \
# zip_code  ...
# 10001     ...            0.959053                  0.726459
# 10002     ...            0.924734                  0.699130
# 10003     ...            0.948861                  0.684703
# 10004     ...            0.983762                  0.658673
# 10005     ...            0.967943                  0.815560
#
#           employedPubSecProportion  employedSelfEmpProportion  \
# zip_code
# 10001                     0.060124                   0.133758
# 10002                     0.102674                   0.111372
# 10003                     0.054752                   0.130395
# 10004                     0.079415                   0.196823
# 10005                     0.068808                   0.058244
#
#           employedPvtNonProProportion  employedUnpaidFamProportion  \
# zip_code
# 10001                        0.079658                     0.000000
# 10002                        0.082401                     0.004423
# 10003                        0.127244                     0.002906
# 10004                        0.053877                     0.011211
# 10005                        0.057388                     0.000000
#
#           insuredProportion  housingRentMoreThan30pcProportion  \
# zip_code
# 10001              0.970333                           0.388259
# 10002              0.944278                           0.505625
# 10003              0.969856                           0.412086
# 10004              0.989364                           0.322658
# 10005              0.990390                           0.348382
#
#           housingMedianValue  housingMedianGrossRent
# zip_code
# 10001               467800.0                  2269.0
# 10002               719500.0                  1047.0
# 10003               972900.0                  2478.0
# 10004              1722600.0                  3501.0
# 10005              1237900.0                  3501.0
#
# [5 rows x 21 columns]

# %%
df.to_csv('preprocessed_2021.csv')
